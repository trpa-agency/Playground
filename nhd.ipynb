# %%
import requests
import urllib.parse
def get_nhd_id(state, name):
    if name.lower() in ['none', 'unknown']:
        return None
    
    base_url = "https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query"
    params = {
        "where": f"gnis_name='{name}''",
        "outFields": "permanent_identifier,gnis_name,gnis_id",
        "f": "json"
    }
    query_url = f"{base_url}?{urllib.parse.urlencode(params)}"
    print(f"\nRequest URL for {state} - {name}:\n{query_url}")
    r = requests.get(base_url, params=params)
    data = r.json()
    if data.get("features"):
        f = data["features"][0]["attributes"]
        return {
            "name": name,
            "Permanent_ID": f.get("permanent_identifier"),
            "GNIS_ID": f.get("gnis_id")
        }
    else:
        return {"state": state, "name": name, "Permanent_ID": None, "GNIS_ID": None}

entries = [
    ("CA", "None"),
    ("CA", "Folsom Lake"),
    ("NV", "Pyramid Lake"),
    ("WA", "Brand New"),
    ("CA", "UNKNOWN"),
    ("NV", "Topaz Lake"),
    ("CA", "Walker Lake"),
    ("OR", "Pacific Ocean")
]

results = [get_nhd_id(state, name) for state, name in entries]
for r in results:
    print(r)
# Out:
# Request URL for CA - Folsom Lake:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Folsom+Lake%27%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
#
# Request URL for NV - Pyramid Lake:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Pyramid+Lake%27%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
#
# Request URL for WA - Brand New:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Brand+New%27%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
#
# Request URL for NV - Topaz Lake:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Topaz+Lake%27%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
#
# Request URL for CA - Walker Lake:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Walker+Lake%27%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
#
# Request URL for OR - Pacific Ocean:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Pacific+Ocean%27%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
# None
# {'state': 'CA', 'name': 'Folsom Lake', 'Permanent_ID': None, 'GNIS_ID': None}
# {'state': 'NV', 'name': 'Pyramid Lake', 'Permanent_ID': None, 'GNIS_ID': None}
# {'state': 'WA', 'name': 'Brand New', 'Permanent_ID': None, 'GNIS_ID': None}
# None
# {'state': 'NV', 'name': 'Topaz Lake', 'Permanent_ID': None, 'GNIS_ID': None}
# {'state': 'CA', 'name': 'Walker Lake', 'Permanent_ID': None, 'GNIS_ID': None}
# {'state': 'OR', 'name': 'Pacific Ocean', 'Permanent_ID': None, 'GNIS_ID': None}

# %%
import requests
import urllib.parse

def get_nhd_id(state, name):
    if name.lower() in ['none', 'unknown']:
        return None

    base_url = "https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query"
    params = {
        "where": f"gnis_name='{name}'",  # <-- fixed: removed extra quote
        "outFields": "permanent_identifier,gnis_name,gnis_id",
        "f": "json"
    }

    query_url = f"{base_url}?{urllib.parse.urlencode(params)}"
    print(f"\nRequest URL for {state} - {name}:\n{query_url}")

    r = requests.get(base_url, params=params)
    data = r.json()

    if data.get("features"):
        f = data["features"][0]["attributes"]
        return {
            "name": name,
            "Permanent_ID": f.get("permanent_identifier"),
            "GNIS_ID": f.get("gnis_id")
        }
    else:
        return {"state": state, "name": name, "Permanent_ID": None, "GNIS_ID": None}

entries = [
    ("CA", "None"),
    ("CA", "Folsom Lake"),
    ("NV", "Pyramid Lake"),
    ("WA", "Brand New"),
    ("CA", "UNKNOWN"),
    ("NV", "Topaz Lake"),
    ("CA", "Walker Lake"),
    ("OR", "Pacific Ocean")
]

results = [get_nhd_id(state, name) for state, name in entries]

for r in results:
    print(r)
# Out:
# Request URL for CA - Folsom Lake:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Folsom+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
#
# Request URL for NV - Pyramid Lake:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Pyramid+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
#
# Request URL for WA - Brand New:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Brand+New%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
#
# Request URL for NV - Topaz Lake:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Topaz+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
#
# Request URL for CA - Walker Lake:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Walker+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
#
# Request URL for OR - Pacific Ocean:
# https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name%3D%27Pacific+Ocean%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&f=json
# None
# {'name': 'Folsom Lake', 'Permanent_ID': '63434918', 'GNIS_ID': '00223648'}
# {'name': 'Pyramid Lake', 'Permanent_ID': 'A9BB37A3-93AD-4F51-B6EF-D0D30896857B', 'GNIS_ID': '-1'}
# {'state': 'WA', 'name': 'Brand New', 'Permanent_ID': None, 'GNIS_ID': None}
# None
# {'name': 'Topaz Lake', 'Permanent_ID': '{4A155037-15D6-4D8C-90CF-E5E25BE4994D}', 'GNIS_ID': '-1'}
# {'name': 'Walker Lake', 'Permanent_ID': '124186445', 'GNIS_ID': '00704589'}
# {'name': 'Pacific Ocean', 'Permanent_ID': 'cfe7ce55-4891-4659-9cc0-d4b463b6a568', 'GNIS_ID': '00247074'}

# %%
import pandas as pd

# %%
import arcpy
import pandas as pd
import requests
import urllib.parse
import tempfile
import os

# ======================
# Configuration
# ======================
csv_path = r"source_waters.csv"
out_gdb = r"C:\GIS\Scratch.gdb"
out_fc = "NHD_Waterbodies_Combined"

# NHDPlus_HR MapServer (Waterbody layer)
BASE_URL = "https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query"

# ======================
# Functions
# ======================
def get_nhd_records(state, name):
    """Return *all* NHD features matching a given GNIS name."""
    if pd.isna(name) or str(name).lower() in ["none", "unknown"]:
        return [{
            "State": state, "Waterbody": name,
            "Permanent_ID": None, "GNIS_ID": None,
            "GNIS_Name": name, "geometry": None
        }]

    params = {
        "where": f"gnis_name = '{name}'",
        "outFields": "permanent_identifier,gnis_name,gnis_id",
        "returnGeometry": "true",
        "f": "json"
    }

    r = requests.get(BASE_URL, params=params)
    data = r.json()

    features = data.get("features", [])
    if not features:
        return [{
            "State": state, "Waterbody": name,
            "Permanent_ID": None, "GNIS_ID": None,
            "GNIS_Name": name, "geometry": None
        }]

    records = []
    for f in features:
        attrs = f["attributes"]
        geom = f["geometry"]
        records.append({
            "State": state,
            "Waterbody": name,
            "Permanent_ID": attrs.get("permanent_identifier"),
            "GNIS_ID": attrs.get("gnis_id"),
            "GNIS_Name": attrs.get("gnis_name"),
            "geometry": geom
        })
    return records


# ======================
# Main processing
# ======================
print("Reading input CSV...")
df = pd.read_csv(csv_path)

all_records = []
for _, row in df.iterrows():
    matches = get_nhd_records(row["State"], row["Waterbody"])
    for m in matches:
        # Combine CSV fields with NHD attributes
        m.update({
            "Count": row.get("Count"),
            "NAS_Infested": row.get("NAS_Infested"),
            "Manual_Override": row.get("Manual_Override")
        })
    all_records.extend(matches)

print(f"Total combined rows: {len(all_records)}")

# Convert to DataFrame
result_df = pd.DataFrame(all_records)

# ======================
# Convert JSON geometries to shapefiles via temp feature class
# ======================
temp_json = os.path.join(tempfile.gettempdir(), "nhd_temp.json")

# Filter out null geometries for those with no matches
matched = result_df[result_df["geometry"].notna()].copy()

if not matched.empty:
    # Write to JSON for ArcGIS conversion
    features = {
        "displayFieldName": "",
        "fieldAliases": {},
        "geometryType": "esriGeometryPolygon",
        "spatialReference": {"wkid": 4326},
        "fields": [],
        "features": [
            {"geometry": g, "attributes": {"idx": i}}
            for i, g in enumerate(matched["geometry"])
        ],
    }

    import json
    with open(temp_json, "w") as f:
        json.dump(features, f)

    arcpy.JSONToFeatures_conversion(temp_json, os.path.join(out_gdb, "temp_nhd"))
    temp_fc = os.path.join(out_gdb, "temp_nhd")

    # Add table attributes
    temp_sdf = arcpy.da.FeatureClassToNumPyArray(temp_fc, ["SHAPE@XY"])
else:
    temp_fc = None

# ======================
# Build final output table
# ======================
print("Writing final feature class...")

if temp_fc:
    # If we have geometries, convert result_df to Spatially Enabled DataFrame
    sdf = arcpy.da.NumPyArrayToTable(temp_sdf, os.path.join(out_gdb, "nhd_table"))
    # Add all attribute fields and join
    arcpy.management.AddField(temp_fc, "State", "TEXT")
    arcpy.management.AddField(temp_fc, "Waterbody", "TEXT")
    arcpy.management.AddField(temp_fc, "Permanent_ID", "TEXT")
    arcpy.management.AddField(temp_fc, "GNIS_ID", "TEXT")
    arcpy.management.AddField(temp_fc, "Count", "LONG")
    arcpy.management.AddField(temp_fc, "NAS_Infested", "TEXT")
    arcpy.management.AddField(temp_fc, "Manual_Override", "TEXT")

    # Could populate via update cursor here if needed.
    # (Simplified here for readability)

    arcpy.management.CopyFeatures(temp_fc, os.path.join(out_gdb, out_fc))
else:
    # No matches — create an empty feature class
    sr = arcpy.SpatialReference(4326)
    arcpy.management.CreateFeatureclass(out_gdb, out_fc, "POLYGON", spatial_reference=sr)
    print("No geometries found, empty feature class created.")

print(f"✅ Done. Output: {os.path.join(out_gdb, out_fc)}")
# Out:
# Reading input CSV...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[11], line 71
#      69 all_records = []
#      70 for _, row in df.iterrows():
# ---> 71     matches = get_nhd_records(row["State"], row["Waterbody"])
#      72     for m in matches:
#      73         # Combine CSV fields with NHD attributes
#      74         m.update({
#      75             "Count": row.get("Count"),
#      76             "NAS_Infested": row.get("NAS_Infested"),
#      77             "Manual_Override": row.get("Manual_Override")
#      78         })
#
# Cell In[11], line 38, in get_nhd_records(state, name)
#      30 params = {
#      31     "where": f"gnis_name = '{name}'",
#      32     "outFields": "permanent_identifier,gnis_name,gnis_id",
#      33     "returnGeometry": "true",
#      34     "f": "json"
#      35 }
#      37 r = requests.get(BASE_URL, params=params)
# ---> 38 data = r.json()
#      40 features = data.get("features", [])
#      41 if not features:
#
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import arcpy
import pandas as pd
import requests
import urllib.parse
import json
import os
from arcgis.features import GeoAccessor, GeoSeriesAccessor

# ======================
# CONFIG
# ======================
csv_path = r"source_waters.csv"
out_gdb = r"C:\GIS\Scratch.gdb"
out_fc = "NHD_Waterbodies_Combined"

BASE_URL = "https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query"

# ======================
# FUNCTION
# ======================
def get_nhd_records(state, name):
    """Query NHD for all features matching GNIS name."""
    if pd.isna(name) or str(name).lower() in ["none", "unknown"]:
        return [{
            "State": state,
            "Waterbody": name,
            "Permanent_ID": None,
            "GNIS_ID": None,
            "GNIS_Name": name,
            "geometry": None
        }]
    
    # Build query
    params = {
        "where": f"gnis_name = '{name}'",
        "outFields": "permanent_identifier,gnis_name,gnis_id",
        "returnGeometry": "true",
        "f": "json"
    }
    query_url = f"{BASE_URL}?{urllib.parse.urlencode(params)}"
    
    # Print for debug
    print(f"\n=== Querying {state} - {name} ===")
    print(f"URL: {query_url}")
    
    try:
        r = requests.get(BASE_URL, params=params, timeout=30)
        r.raise_for_status()
        data = r.json()
    except requests.exceptions.RequestException as e:
        print(f"⚠️ Request failed for {name}: {e}")
        return [{
            "State": state, "Waterbody": name,
            "Permanent_ID": None, "GNIS_ID": None,
            "GNIS_Name": name, "geometry": None
        }]
    except json.JSONDecodeError:
        print(f"⚠️ Invalid JSON returned for {name}. Skipping.")
        return [{
            "State": state, "Waterbody": name,
            "Permanent_ID": None, "GNIS_ID": None,
            "GNIS_Name": name, "geometry": None
        }]

    features = data.get("features", [])
    if not features:
        print(f"ℹ️ No matches found for {name}")
        return [{
            "State": state, "Waterbody": name,
            "Permanent_ID": None, "GNIS_ID": None,
            "GNIS_Name": name, "geometry": None
        }]

    records = []
    for f in features:
        attrs = f["attributes"]
        geom = f.get("geometry")
        records.append({
            "State": state,
            "Waterbody": name,
            "Permanent_ID": attrs.get("permanent_identifier"),
            "GNIS_ID": attrs.get("gnis_id"),
            "GNIS_Name": attrs.get("gnis_name"),
            "geometry": geom
        })
    print(f"✅ Found {len(records)} feature(s) for {name}")
    return records


# ======================
# MAIN PROCESS
# ======================
print("Reading input CSV...")
df = pd.read_csv(csv_path)

all_records = []
for _, row in df.iterrows():
    matches = get_nhd_records(row["State"], row["Waterbody"])
    for m in matches:
        # Add CSV attributes
        m.update({
            "Count": row.get("Count"),
            "NAS_Infested": row.get("NAS_Infested"),
            "Manual_Override": row.get("Manual_Override")
        })
    all_records.extend(matches)

print(f"\nTotal records after expansion: {len(all_records)}")

result_df = pd.DataFrame(all_records)

# Convert geometry dicts to ArcGIS geometries for Spatially Enabled DataFrame
def arcgis_geom(g):
    if not g:
        return None
    try:
        return {"rings": g["rings"]} if "rings" in g else {"paths": g["paths"]}
    except Exception:
        return None

result_df["SHAPE"] = result_df["geometry"].apply(arcgis_geom)

# Convert to Spatially Enabled DataFrame
sdf = GeoAccessor.from_df(result_df, geometry_column="SHAPE", sr=4326)

# ======================
# SAVE OUTPUT
# ======================
out_path = os.path.join(out_gdb, out_fc)
print(f"\nWriting to {out_path} ...")
sdf.spatial.to_featureclass(location=out_path, sanitize_columns=True)
print("✅ Done! Spatial feature class created successfully.")
# Out:
# Reading input CSV...
#
# === Querying CA - Tenaya Lake - Yosemite NP ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Tenaya+Lake+-+Yosemite+NP%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Tenaya Lake - Yosemite NP
#
# === Querying CA - Pacific - San Pedro Bay ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Pacific+-+San+Pedro+Bay%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Pacific - San Pedro Bay
#
# === Querying CA - Sacramento River - Ord bend ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Sacramento+River+-+Ord+bend%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Sacramento River - Ord bend
#
# === Querying ID - Henrys Fork Snake River - Lower ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Henrys+Fork+Snake+River+-+Lower%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Henrys Fork Snake River - Lower
#
# === Querying ID - Snake River - Burley ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Snake+River+-+Burley%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Snake River - Burley
#
# === Querying CA - Petaluma - Black Point ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Petaluma+-+Black+Point%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Petaluma - Black Point
#
# === Querying CA - Stampede Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Stampede+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Stampede Reservoir
#
# === Querying CA - Folsom Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Folsom+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 6 feature(s) for Folsom Lake
#
# === Querying NV - Pyramid Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Pyramid+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 13 feature(s) for Pyramid Lake
#
# === Querying WA - Brand New ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Brand+New%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Brand New
#
# === Querying NV - Topaz Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Topaz+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 5 feature(s) for Topaz Lake
#
# === Querying CA - Walker Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Walker+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 58 feature(s) for Walker Lake
#
# === Querying OR - Pacific Ocean ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Pacific+Ocean%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 3 feature(s) for Pacific Ocean
#
# === Querying CA - Sacramento Delta ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Sacramento+Delta%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Sacramento Delta
#
# === Querying CA - Frenchman Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Frenchman+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 5 feature(s) for Frenchman Lake
#
# === Querying AB - Albright Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Albright+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Albright Lake
#
# === Querying AB - Battle Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Battle+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 8 feature(s) for Battle Lake
#
# === Querying CA - Donner Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Donner+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Donner Lake
#
# === Querying AB - Athabasca River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Athabasca+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Athabasca River
#
# === Querying AB - Barrier Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Barrier+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Barrier Lake
#
# === Querying AB - Big Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Big+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 138 feature(s) for Big Lake
#
# === Querying CA - Lake Tahoe ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Tahoe%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 6 feature(s) for Lake Tahoe
#
# === Querying CA - Camanche Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Camanche+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Camanche Reservoir
#
# === Querying FL - Atlantic Ocean ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Atlantic+Ocean%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Atlantic Ocean
#
# === Querying NV - Lake Tahoe ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Tahoe%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 6 feature(s) for Lake Tahoe
#
# === Querying CA - Clear Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Clear+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 287 feature(s) for Clear Lake
#
# === Querying NV - Lahontan Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lahontan+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lahontan Reservoir
#
# === Querying CA - Jenkinson Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Jenkinson+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Jenkinson Lake
#
# === Querying CA - Davis Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Davis+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 83 feature(s) for Davis Lake
#
# === Querying TN - Lake chickamauga ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+chickamauga%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake chickamauga
#
# === Querying CA - Lake topaz ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+topaz%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake topaz
#
# === Querying CA - Monterey Bay (Pacific Ocean) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Monterey+Bay+%28Pacific+Ocean%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Monterey Bay (Pacific Ocean)
#
# === Querying CA - Discovery Bay ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Discovery+Bay%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Discovery Bay
#
# === Querying CA - Union Valley Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Union+Valley+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Union Valley Reservoir
#
# === Querying WA - Pacific Ocean ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Pacific+Ocean%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 3 feature(s) for Pacific Ocean
#
# === Querying CA - Modesto Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Modesto+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Modesto Reservoir
#
# === Querying CA - Mission Bay (Pacific Ocean) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Mission+Bay+%28Pacific+Ocean%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Mission Bay (Pacific Ocean)
#
# === Querying CA - Bridgeport Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Bridgeport+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 2 feature(s) for Bridgeport Reservoir
#
# === Querying AZ - Lake Powell ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Powell%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 7 feature(s) for Lake Powell
#
# === Querying CA - Long Beach (Pacific Ocean) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Long+Beach+%28Pacific+Ocean%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Long Beach (Pacific Ocean)
#
# === Querying CA - San pedro lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27San+pedro+lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for San pedro lake
#
# === Querying CA - Topaz Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Topaz+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 5 feature(s) for Topaz Lake
#
# === Querying CA - sky park reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27sky+park+reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for sky park reservoir
#
# === Querying TX - Conroe Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Conroe+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Conroe Lake
#
# === Querying CA - sacramento river ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27sacramento+river%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for sacramento river
#
# === Querying AZ - Lake Havasu ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Havasu%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake Havasu
#
# === Querying CA - Huntington Beach (Pacific Ocean) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Huntington+Beach+%28Pacific+Ocean%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Huntington Beach (Pacific Ocean)
#
# === Querying GA - State of Georgia ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27State+of+Georgia%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for State of Georgia
#
# === Querying CA - Lake Elsinore ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Elsinore%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake Elsinore
#
# === Querying CA - San Francisco Bay (Pacific Ocean) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27San+Francisco+Bay+%28Pacific+Ocean%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for San Francisco Bay (Pacific Ocean)
#
# === Querying CA - Lake almanor ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+almanor%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake almanor
#
# === Querying CA - New Bullards Bar Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27New+Bullards+Bar+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for New Bullards Bar Reservoir
#
# === Querying CA - Lake of the Pines ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+of+the+Pines%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 7 feature(s) for Lake of the Pines
#
# === Querying CA - Fallen Leaf Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Fallen+Leaf+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Fallen Leaf Lake
#
# === Querying CA - Bucks Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Bucks+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 3 feature(s) for Bucks Lake
#
# === Querying KS - State of Kansas ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27State+of+Kansas%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for State of Kansas
#
# === Querying TX - Lake Louisville ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Louisville%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake Louisville
#
# === Querying CA - Lake Perris ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Perris%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake Perris
#
# === Querying CA - Whiskeytown Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Whiskeytown+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Whiskeytown Lake
#
# === Querying CA - Colorado River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Colorado+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Colorado River
#
# === Querying CA - Rollins Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Rollins+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Rollins Reservoir
#
# === Querying ID - Coeur dAlene Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Coeur+dAlene+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Coeur dAlene Lake
#
# === Querying MO - Lake of the Ozarks ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+of+the+Ozarks%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 2 feature(s) for Lake of the Ozarks
#
# === Querying UT - Lake Powell ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Powell%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 7 feature(s) for Lake Powell
#
# === Querying OR - Billy Chinook Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Billy+Chinook+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Billy Chinook Lake
#
# === Querying AB - 40 Mile Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%2740+Mile+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for 40 Mile Lake
#
# === Querying CA - Comanche Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Comanche+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 5 feature(s) for Comanche Lake
#
# === Querying SC - Lake Keowee ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Keowee%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake Keowee
#
# === Querying AZ - Lake Pleasant ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Pleasant%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 11 feature(s) for Lake Pleasant
#
# === Querying FL - Fort Walton Beach (Gulf of Mexico) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Fort+Walton+Beach+%28Gulf+of+Mexico%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Fort Walton Beach (Gulf of Mexico)
#
# === Querying UT - Quail Creek Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Quail+Creek+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 2 feature(s) for Quail Creek Reservoir
#
# === Querying CA - Caples Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Caples+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Caples Lake
#
# === Querying ID - State of Idaho ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27State+of+Idaho%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for State of Idaho
#
# === Querying CA - June lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27June+lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for June lake
#
# === Querying CA - Rawlins ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Rawlins%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Rawlins
#
# === Querying OR - Willamtte River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Willamtte+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Willamtte River
#
# === Querying CA - Cascade Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Cascade+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 18 feature(s) for Cascade Lake
#
# === Querying CA - Lake Orovill ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Orovill%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake Orovill
#
# === Querying CA - Camp Far West Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Camp+Far+West+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Camp Far West Reservoir
#
# === Querying CA - Bullards Bar Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Bullards+Bar+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Bullards Bar Reservoir
#
# === Querying OR - Columbia River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Columbia+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Columbia River
#
# === Querying CA - American River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27American+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for American River
#
# === Querying CA - Lake Berryessa ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Berryessa%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake Berryessa
#
# === Querying CT - Atlantic Ocean ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Atlantic+Ocean%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Atlantic Ocean
#
# === Querying CA - Almanor Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Almanor+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Almanor Lake
#
# === Querying CA - Bodega Bay (Pacific Ocean) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Bodega+Bay+%28Pacific+Ocean%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Bodega Bay (Pacific Ocean)
#
# === Querying CA - Bass Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Bass+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 236 feature(s) for Bass Lake
#
# === Querying CA - Scotts Flat Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Scotts+Flat+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Scotts Flat Reservoir
#
# === Querying CA - San Joaquin delta ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27San+Joaquin+delta%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for San Joaquin delta
#
# === Querying CA - Sly Creek reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Sly+Creek+reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Sly Creek reservoir
#
# === Querying CA - Lake Wildwood ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Wildwood%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 9 feature(s) for Lake Wildwood
#
# === Querying CA - Boca Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Boca+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Boca Reservoir
#
# === Querying CA - Shasta Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Shasta+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 3 feature(s) for Shasta Lake
#
# === Querying CA - Don Pedro Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Don+Pedro+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Don Pedro Reservoir
#
# === Querying NV - State of Nevada ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27State+of+Nevada%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for State of Nevada
#
# === Querying CA - Calero Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Calero+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Calero Reservoir
#
# === Querying CA - Big Bear Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Big+Bear+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 15 feature(s) for Big Bear Lake
#
# === Querying CA - Lake Sonoma ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Sonoma%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 2 feature(s) for Lake Sonoma
#
# === Querying NV - Wild Horse Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Wild+Horse+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 8 feature(s) for Wild Horse Reservoir
#
# === Querying CA - Echo Lakes ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Echo+Lakes%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Echo Lakes
#
# === Querying CA - pedaluma river ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27pedaluma+river%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for pedaluma river
#
# === Querying CA - Santa Margarita Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Santa+Margarita+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Santa Margarita Lake
#
# === Querying CA - Don Pedro Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Don+Pedro+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Don Pedro Lake
#
# === Querying CA - French Meadows Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27French+Meadows+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for French Meadows Reservoir
#
# === Querying NV - South Fork Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27South+Fork+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 5 feature(s) for South Fork Reservoir
#
# === Querying AB - Pyramid Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Pyramid+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 13 feature(s) for Pyramid Lake
#
# === Querying CO - Carter Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Carter+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 40 feature(s) for Carter Lake
#
# === Querying CA - Antelope Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Antelope+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 19 feature(s) for Antelope Lake
#
# === Querying TX - Corpus Christi Bay ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Corpus+Christi+Bay%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Corpus Christi Bay
#
# === Querying CA - Englebright Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Englebright+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Englebright Lake
#
# === Querying CA - California Delta ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27California+Delta%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for California Delta
#
# === Querying MN - Upper Prior Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Upper+Prior+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Upper Prior Lake
#
# === Querying AZ - Apache Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Apache+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 5 feature(s) for Apache Lake
#
# === Querying CA - Tamales Bay ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Tamales+Bay%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Tamales Bay
#
# === Querying CA - Marina del Ray (Pacific Ocean) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Marina+del+Ray+%28Pacific+Ocean%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Marina del Ray (Pacific Ocean)
#
# === Querying TX - Lewisville Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lewisville+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lewisville Lake
#
# === Querying MI - Gull Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Gull+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 24 feature(s) for Gull Lake
#
# === Querying CA - Combie Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Combie+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Combie Lake
#
# === Querying CA - Lake Natoma ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Natoma%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake Natoma
#
# === Querying CA - Pyramid Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Pyramid+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 13 feature(s) for Pyramid Lake
#
# === Querying OK - State of Oklahoma ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27State+of+Oklahoma%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for State of Oklahoma
#
# === Querying NM - Elephant Butte Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Elephant+Butte+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Elephant Butte Reservoir
#
# === Querying CA - tahoe ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27tahoe%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for tahoe
#
# === Querying CA - Anderson Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Anderson+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 92 feature(s) for Anderson Lake
#
# === Querying CA - Shadow Cliffs Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Shadow+Cliffs+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Shadow Cliffs Reservoir
#
# === Querying CA - San Diego Bay (Pacific Ocean) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27San+Diego+Bay+%28Pacific+Ocean%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for San Diego Bay (Pacific Ocean)
#
# === Querying MI - State of Michigan ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27State+of+Michigan%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for State of Michigan
#
# === Querying CA - Ice House Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Ice+House+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Ice House Reservoir
#
# === Querying CO - Boulder Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Boulder+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 3 feature(s) for Boulder Reservoir
#
# === Querying CA - Lake Davis ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Davis%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 5 feature(s) for Lake Davis
#
# === Querying AZ - Colorado River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Colorado+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Colorado River
#
# === Querying CA - aquatic park ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27aquatic+park%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for aquatic park
#
# === Querying CA - Paradise Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Paradise+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 50 feature(s) for Paradise Lake
#
# === Querying ID - Bear Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Bear+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 182 feature(s) for Bear Lake
#
# === Querying CA - Convict Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Convict+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 2 feature(s) for Convict Lake
#
# === Querying CA - Santa Cruz Harbor (Pacific Ocean) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Santa+Cruz+Harbor+%28Pacific+Ocean%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Santa Cruz Harbor (Pacific Ocean)
#
# === Querying CA - Lake Forest ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Forest%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 13 feature(s) for Lake Forest
#
# === Querying CA - Stumpy Meadows ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Stumpy+Meadows%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Stumpy Meadows
#
# === Querying CA - Eagle Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Eagle+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 101 feature(s) for Eagle Lake
#
# === Querying AZ - Black Canyon Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Black+Canyon+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 2 feature(s) for Black Canyon Lake
#
# === Querying OR - Lyte ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lyte%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lyte
#
# === Querying CA - OCEAN half moon bay ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27OCEAN+half+moon+bay%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for OCEAN half moon bay
#
# === Querying CA - New Melones Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27New+Melones+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for New Melones Lake
#
# === Querying CA - Lake McClure ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+McClure%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 2 feature(s) for Lake McClure
#
# === Querying CA - Orville lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Orville+lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Orville lake
#
# === Querying CA - Lexington Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lexington+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 5 feature(s) for Lexington Reservoir
#
# === Querying CA - Lake Tulloch ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Tulloch%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake Tulloch
#
# === Querying CA - does not work ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27does+not+work%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for does not work
#
# === Querying AZ - Lake Mohave ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Mohave%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake Mohave
#
# === Querying AR - Colorado River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Colorado+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Colorado River
#
# === Querying ID - Coral Creek Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Coral+Creek+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Coral Creek Reservoir
#
# === Querying OR - Wilamette River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Wilamette+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Wilamette River
#
# === Querying MO - State of Missouri ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27State+of+Missouri%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for State of Missouri
#
# === Querying UT - Jordanelle Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Jordanelle+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Jordanelle Reservoir
#
# === Querying CA - Lake del Valle ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+del+Valle%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake del Valle
#
# === Querying AZ - Bartlett Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Bartlett+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 5 feature(s) for Bartlett Lake
#
# === Querying CA - Collins Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Collins+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 26 feature(s) for Collins Lake
#
# === Querying CA - Lake Don Pedro ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Don+Pedro%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake Don Pedro
#
# === Querying CA - East Park Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27East+Park+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 3 feature(s) for East Park Reservoir
#
# === Querying CO - Boyd Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Boyd+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 18 feature(s) for Boyd Lake
#
# === Querying TX - Lake Austin ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Austin%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 4 feature(s) for Lake Austin
#
# === Querying CT - Connecticut River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Connecticut+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Connecticut River
#
# === Querying WA - Lake Washington ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Washington%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 13 feature(s) for Lake Washington
#
# === Querying OR - Pine Hollow Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Pine+Hollow+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Pine Hollow Reservoir
#
# === Querying CA - Lake Oroville ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Oroville%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 3 feature(s) for Lake Oroville
#
# === Querying CA - Yosemite Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Yosemite+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 2 feature(s) for Yosemite Lake
#
# === Querying TX - State of Texas ===
# ...
# ✅ Found 2 feature(s) for Courtright Reservoir
#
# === Querying PR - Atlantic Ocean ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Atlantic+Ocean%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Atlantic Ocean
#
# === Querying MI - Lake Mitchell ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Mitchell%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 7 feature(s) for Lake Mitchell
#
# === Querying CA - Grant Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Grant+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 28 feature(s) for Grant Lake
#
# === Querying IN - Lake Wawasee ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Wawasee%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake Wawasee
#
# === Querying CA - Lake Hennessy ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Hennessy%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake Hennessy
#
# === Querying CA - Castle lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Castle+lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Castle lake
#
# === Querying CA - Lake Combie ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Combie%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake Combie
#
# === Querying CA - Lower Twin Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lower+Twin+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 14 feature(s) for Lower Twin Lake
#
# === Querying MD - Chesapeake Bay ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Chesapeake+Bay%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 7 feature(s) for Chesapeake Bay
#
# === Querying CA - Angora Lakes ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Angora+Lakes%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 3 feature(s) for Angora Lakes
#
# === Querying MT - Whitefish Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Whitefish+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 24 feature(s) for Whitefish Lake
#
# === Querying MT - Canyon Ferry Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Canyon+Ferry+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Canyon Ferry Reservoir
#
# === Querying NC - Jordan Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Jordan+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 22 feature(s) for Jordan Lake
#
# === Querying IL - Ohio River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Ohio+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Ohio River
#
# === Querying OR - Triangle Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Triangle+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 32 feature(s) for Triangle Lake
#
# === Querying CA - San Luis Obispo Bay (Pacific Ocean) ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27San+Luis+Obispo+Bay+%28Pacific+Ocean%29%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for San Luis Obispo Bay (Pacific Ocean)
#
# === Querying CA - lake collins ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27lake+collins%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for lake collins
#
# === Querying CA - Shore Line Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Shore+Line+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Shore Line Lake
#
# === Querying SC - Hartwell Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Hartwell+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 2 feature(s) for Hartwell Lake
#
# === Querying MN - Lake Washington ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Washington%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 13 feature(s) for Lake Washington
#
# === Querying CA - Uvas Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Uvas+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Uvas Reservoir
#
# === Querying OR - Olalla Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Olalla+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Olalla Reservoir
#
# === Querying FL - Davenport Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Davenport+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 5 feature(s) for Davenport Lake
#
# === Querying FL - lake davenport ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27lake+davenport%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for lake davenport
#
# === Querying ID - Black Canyon Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Black+Canyon+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 7 feature(s) for Black Canyon Reservoir
#
# === Querying CA - Lake Naicimiento ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Naicimiento%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake Naicimiento
#
# === Querying FL - Okeechobee Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Okeechobee+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Okeechobee Lake
#
# === Querying ID - Payette Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Payette+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Payette Lake
#
# === Querying ID - Pend Oreille Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Pend+Oreille+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Pend Oreille Lake
#
# === Querying UT - Scofield Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Scofield+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Scofield Reservoir
#
# === Querying CO - Pueblo Reservoir ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Pueblo+Reservoir%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 2 feature(s) for Pueblo Reservoir
#
# === Querying CA - Tuolumne River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Tuolumne+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Tuolumne River
#
# === Querying UT - Jordan River ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Jordan+River%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Jordan River
#
# === Querying WA - Bosworth Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Bosworth+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Bosworth Lake
#
# === Querying MI - Lake Mecosta ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Mecosta%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake Mecosta
#
# === Querying CA - Del Belle Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Del+Belle+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Del Belle Lake
#
# === Querying TX - Lake Ray Hubbard ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Ray+Hubbard%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Lake Ray Hubbard
#
# === Querying OR - Loon Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Loon+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 133 feature(s) for Loon Lake
#
# === Querying OR - Upper Klamath Lake ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Upper+Klamath+Lake%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Upper Klamath Lake
#
# === Querying OR - Yaquina Bay ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Yaquina+Bay%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Yaquina Bay
#
# === Querying OR - Winchester Bay ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Winchester+Bay%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ℹ️ No matches found for Winchester Bay
#
# === Querying NC - Lake Wylie ===
# URL: https://hydro.nationalmap.gov/arcgis/rest/services/NHDPlus_HR/MapServer/9/query?where=gnis_name+%3D+%27Lake+Wylie%27&outFields=permanent_identifier%2Cgnis_name%2Cgnis_id&returnGeometry=true&f=json
# ✅ Found 1 feature(s) for Lake Wylie
#
# Total records after expansion: 9393
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\arcgis\features\geo\_accessor.py:4148, in GeoAccessor.project(self, spatial_reference, transformation_name)
#    4147 spatial_reference = arcpy.SpatialReference(spatial_reference)
# -> 4148 vals = self._data[self.name].values.project_as(
#    4149     **{
#    4150         "spatial_reference": spatial_reference,
#    4151         "transformation_name": transformation_name,
#    4152     }
#    4153 )
#    4154 self._data[self.name] = vals
#
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\arcgis\features\geo\_array.py:1309, in GeoArray.project_as(self, spatial_reference, transformation_name)
#    1295 """
#    1296 Projects a geometry and optionally applies a geotransformation.
#    1297
#    (...)
#    1307 :return: arcgis.geometry.Geometry
#    1308 """
# -> 1309 return _binary_op_geo(
#    1310     name="project_as",
#    1311     left=self.data,
#    1312     **{
#    1313         "spatial_reference": spatial_reference,
#    1314         "transformation_name": transformation_name,
#    1315     },
#    1316 )
#
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\arcgis\features\geo\_array.py:181, in _binary_op_geo(name, left, right, *args, **kwargs)
#     180 data = np.empty(len(left), dtype=object)
# --> 181 data[:] = [
#     182     (getattr(s, name)(*args, **kwargs) if s is not None else null_value)
#     183     for s in left
#     184 ]
#     185 return GeoArray(data)
#
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\arcgis\features\geo\_array.py:182, in <listcomp>(.0)
#     180 data = np.empty(len(left), dtype=object)
#     181 data[:] = [
# --> 182     (getattr(s, name)(*args, **kwargs) if s is not None else null_value)
#     183     for s in left
#     184 ]
#     185 return GeoArray(data)
#
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\arcgis\geometry\_types.py:2877, in Geometry.project_as(self, spatial_reference, transformation_name)
#    2875         raise ValueError("Invalid spatial reference object.")
#    2876     return Geometry(
# -> 2877         self.as_arcpy.projectAs(
#    2878             spatial_reference=spatial_reference,
#    2879             transformation_name=transformation_name,
#    2880         )
#    2881     )
#    2883 try:
#
# AttributeError: 'NoneType' object has no attribute 'projectAs'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 124
#     121 result_df["SHAPE"] = result_df["geometry"].apply(arcgis_geom)
#     123 # Convert to Spatially Enabled DataFrame
# --> 124 sdf = GeoAccessor.from_df(result_df, geometry_column="SHAPE", sr=4326)
#     126 # ======================
#     127 # SAVE OUTPUT
#     128 # ======================
#     129 out_path = os.path.join(out_gdb, out_fc)
#
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\arcgis\features\geo\_accessor.py:2557, in GeoAccessor.from_df(df, address_column, geocoder, sr, geometry_column)
#    2555     df[geometry_column] = GeoArray(series)
#    2556     df.spatial.set_geometry(geometry_column)
# -> 2557     df.spatial.project(sr)
#    2558     return df
#    2559 else:
#
# File c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\arcgis\features\geo\_accessor.py:4193, in GeoAccessor.project(self, spatial_reference, transformation_name)
#    4191         return False
#    4192 except Exception as e:
# -> 4193     raise Exception(e)
#
# Exception: 'NoneType' object has no attribute 'projectAs'

# %%
nhd = get_fs_data('https://hydro.nationalmap.gov/arcgis/rest/services/nhd/MapServer/0')
# Out:
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\amcclary\AppData\Local\ESRI\conda\envs\arcgispro-py3-plotly\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hydro.nationalmap.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
